# %%
import pandas as pd
import numpy as np
import json
import requests

# %%
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %%
keys_g = get_keys("/Users/amooney/.secret/gbooks_api.json")
g_api_key = keys_g['api_key']

# %%
response = requests.get(f'https://www.googleapis.com/books/v1/volumes?q=flowers+inauthor:keyes&key={g_api_key}')

# %%
response
# Out:
# <Response [200]>

# %%
pd.json_normalize(response.json()['items']).columns
# Out:
# Index(['kind', 'id', 'etag', 'selfLink', 'volumeInfo.title',
#        'volumeInfo.subtitle', 'volumeInfo.authors', 'volumeInfo.publisher',
#        'volumeInfo.publishedDate', 'volumeInfo.description',
#        'volumeInfo.industryIdentifiers', 'volumeInfo.readingModes.text',
#        'volumeInfo.readingModes.image', 'volumeInfo.pageCount',
#        'volumeInfo.printType', 'volumeInfo.categories',
#        'volumeInfo.averageRating', 'volumeInfo.ratingsCount',
#        'volumeInfo.maturityRating', 'volumeInfo.allowAnonLogging',
#        'volumeInfo.contentVersion',
#        'volumeInfo.panelizationSummary.containsEpubBubbles',
#        'volumeInfo.panelizationSummary.containsImageBubbles',
#        'volumeInfo.imageLinks.smallThumbnail',
#        'volumeInfo.imageLinks.thumbnail', 'volumeInfo.language',
#        'volumeInfo.previewLink', 'volumeInfo.infoLink',
#        'volumeInfo.canonicalVolumeLink', 'saleInfo.country',
# ...

# %%
df = pd.json_normalize(response.json()['items'])

# %%
pd.options.display.max_columns = 500

# %%
df
# Out:
#            kind            id         etag  \
# 0  books#volume  8Pr_kLFxciYC  excAQXdVF8M
# 1  books#volume  JLunPwAACAAJ  dckVvmyyLz4
# 2  books#volume  F1wgqlNi8AMC  t63yeFXFzRc
# 3  books#volume  9ygPPQAACAAJ  dyzWAEDNzCk
# 4  books#volume  PDTD2hPNcjAC  3qb9gC1SOKg
# 5  books#volume  gK98gXR8onwC  HCBLNKE/WsQ
# 6  books#volume  -Tq3xgEACAAJ  VLAAellpQo0
# 7  books#volume  gK98gXR8onwC  vZKu1aGDEfU
# 8  books#volume  _oG_iTxP1pIC  GJRYTdWbkoM
# 9  books#volume  KY_-oAEACAAJ  9SCf5NIW7og
#
#                                             selfLink  \
# 0  https://www.googleapis.com/books/v1/volumes/8P...
# 1  https://www.googleapis.com/books/v1/volumes/JL...
# 2  https://www.googleapis.com/books/v1/volumes/F1...
# 3  https://www.googleapis.com/books/v1/volumes/9y...
# 4  https://www.googleapis.com/books/v1/volumes/PD...
# 5  https://www.googleapis.com/books/v1/volumes/gK...
# 6  https://www.googleapis.com/books/v1/volumes/-T...
# 7  https://www.googleapis.com/books/v1/volumes/gK...
# ...
